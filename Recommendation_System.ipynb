# %% [markdown]
# # Recommendation System

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import ast
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
pd.set_option('display.max_columns',25)
import warnings
warnings.filterwarnings('ignore')

# %%
# importing dataset
movies = pd.read_csv("/content/tmdb_5000_movies.csv")
credits = pd.read_csv("/content/tmdb_5000_credits.csv")

# %%
# Top 5 row of movies dataset
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# Top 5 row of credits dataset
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %%
# merging movies and credits dataset
movies = pd.merge(movies, credits, on = 'title' )

# %%
# merged dataset
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'cast', 'crew'],
#       dtype='object')

# %%
# taking only necessary columns for content recommendation 
content_movies = movies[['movie_id', 'genres' ,'keywords','title','overview', 'cast', 'crew']]

# %%
content_movies.head()
# Out:
#    movie_id                                             genres  \
# 0     19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       285  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2    206647  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     49026  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     49529  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# ...

# %%
content_movies.isnull().sum()
# Out:
# movie_id    0
# genres      0
# keywords    0
# title       0
# overview    3
# cast        0
# crew        0
# dtype: int64

# %%
content_movies.dropna(inplace = True)

# %%
content_movies.isnull().sum()
# Out:
# movie_id    0
# genres      0
# keywords    0
# title       0
# overview    0
# cast        0
# crew        0
# dtype: int64

# %%
content_movies.duplicated().sum()
# Out:
# 0

# %%
# Extracting features values using ast
def convert(text):
    lst = []
    for i in ast.literal_eval(text):
        lst.append(i['name'])
    
    return lst

# %%
content_movies['genres'] = content_movies['genres'].apply(convert)

# %%
content_movies['keywords'] = content_movies['keywords'].apply(convert)

# %%
content_movies.head(1)
# Out:
#    movie_id                                         genres  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords   title  \
# 0  [culture clash, future, space war, space colon...  Avatar
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
def convert1(text):
    count = 0
    lst = []
    for i in ast.literal_eval(text):
        if count < 3 :
            lst.append(i['name'])
            count += 1
        else:
            break
            
    return lst

# %%
content_movies['cast'] = content_movies['cast'].apply(convert1)

# %%
def fetch_director(text):
    lst = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            lst.append(i['name'])
            
    return lst

# %%
content_movies['crew'] = content_movies['crew'].apply(fetch_director)

# %%
content_movies.head()
# Out:
#    movie_id                                         genres  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]
# 1       285                   [Adventure, Fantasy, Action]
# 2    206647                     [Action, Adventure, Crime]
# 3     49026               [Action, Crime, Drama, Thriller]
# 4     49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
def remove_space(text):
    lst = []
    for i in text:
        lst.append(i.replace(" ",""))
        
    return lst

# %%
content_movies['genres'] = content_movies['genres'].apply(remove_space)
content_movies['keywords'] = content_movies['keywords'].apply(remove_space)
content_movies['cast'] = content_movies['cast'].apply(remove_space)
content_movies['crew'] = content_movies['crew'].apply(remove_space)

# %%
content_movies.head()
# Out:
#    movie_id                                        genres  \
# 0     19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1       285                  [Adventure, Fantasy, Action]
# 2    206647                    [Action, Adventure, Crime]
# 3     49026              [Action, Crime, Drama, Thriller]
# 4     49529           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
content_movies['overview'] = content_movies['overview'].apply(lambda x : x.split())

# %%
content_movies.head()
# Out:
#    movie_id                                        genres  \
# 0     19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1       285                  [Adventure, Fantasy, Action]
# 2    206647                    [Action, Adventure, Crime]
# 3     49026              [Action, Crime, Drama, Thriller]
# 4     49529           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
content_movies['tags'] = content_movies['cast'] + content_movies['genres'] + content_movies['keywords'] + content_movies['crew'] + content_movies['overview']

# %%
content_movies.head()
# Out:
#    movie_id                                        genres  \
# 0     19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1       285                  [Adventure, Fantasy, Action]
# 2    206647                    [Action, Adventure, Crime]
# 3     49026              [Action, Crime, Drama, Thriller]
# 4     49529           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
# Final dataset 
final_df = content_movies[['movie_id','title','tags']]

# %%
final_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1  [JohnnyDepp, OrlandoBloom, KeiraKnightley, Adv...
# 2  [DanielCraig, ChristophWaltz, LéaSeydoux, Acti...
# 3  [ChristianBale, MichaelCaine, GaryOldman, Acti...
# 4  [TaylorKitsch, LynnCollins, SamanthaMorton, Ac...

# %%
final_df['tags'] = final_df['tags'].apply(lambda x:" ".join(x))

# %%
final_df['title'] = final_df['title'].str.lower()
final_df['tags'] = final_df['tags'].str.lower()

# %%
final_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    avatar
# 1       285  pirates of the caribbean: at world's end
# 2    206647                                   spectre
# 3     49026                     the dark knight rises
# 4     49529                               john carter
#
#                                                 tags
# 0  samworthington zoesaldana sigourneyweaver acti...
# 1  johnnydepp orlandobloom keiraknightley adventu...
# 2  danielcraig christophwaltz léaseydoux action a...
# 3  christianbale michaelcaine garyoldman action c...
# 4  taylorkitsch lynncollins samanthamorton action...

# %%
# Removing stopwords
def remove_stopwords(text):
    lst = []
    for word in text.split():
        if word not in stopwords.words('english'):
            lst.append(word)
    
    return " ".join(lst)

# %%
final_df['tags'] = final_df['tags'].apply(remove_stopwords)

# %%
# Lemmatization of Data
def lemmitization(text):
    lst = []
    lemmatizer = WordNetLemmatizer()
    for word in text.split():
        lst.append(lemmatizer.lemmatize(word))
        
    return " ".join(lst)

# %%
final_df['tags'] = final_df['tags'].apply(lemmitization)

# %%
final_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    avatar
# 1       285  pirates of the caribbean: at world's end
# 2    206647                                   spectre
# 3     49026                     the dark knight rises
# 4     49529                               john carter
#
#                                                 tags
# 0  samworthington zoesaldana sigourneyweaver acti...
# 1  johnnydepp orlandobloom keiraknightley adventu...
# 2  danielcraig christophwaltz léaseydoux action a...
# 3  christianbale michaelcaine garyoldman action c...
# 4  taylorkitsch lynncollins samanthamorton action...

# %%
# Importing Bert model
model = SentenceTransformer('multi-qa-mpnet-base-dot-v1')

# %%
embedding = model.encode(final_df['tags'].to_list())

# %%
similarity = cosine_similarity(embedding)

# %%
def find_closest(movie):
  movie_split_title = final_df['title'].str.split()  
  i = 0
  for val in movie_split_title:
    if movie in val:
      return i

    i += 1

# %%
def recommend_with_bert(movie):
  movie = movie.lower()
  movie_title = final_df['title'].to_list()
  if movie in movie_title:
    index = final_df[final_df['title'] == movie].index[0]
  else:
    index = find_closest(movie)

  distances = sorted(list(enumerate(similarity[index])), reverse=True, key = lambda x: x[1])
  for i in distances[1:6]:
      print(final_df.iloc[i[0]].title)

# %%
recommend_with_bert('harry')
# Out:
# harry potter and the prisoner of azkaban
# harry potter and the philosopher's stone
# harry potter and the goblet of fire
# harry potter and the chamber of secrets
# harry potter and the order of the phoenix

# %%
recommend_with_bert('batman')
# Out:
# batman
# the dark knight
# batman & robin
# batman returns
# the dark knight rises
